# %% [markdown]
# # Homework 2: BERT on AWS

# %% [markdown]
# In this homework, we will apply the BERT algorithm on Amazon Web Services.
#
# This [DataRec repository](https://github.com/sisinflab/DataRec) contains a pointer to accessing recommendation system data, installable via
#
# ```python
# pip install datarec-lib
# ```

# %%
# %pip install datarec-lib
# Out:
# Collecting datarec-lib
#   Downloading datarec_lib-1.5.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.23 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from datarec-lib) (1.26.4)
# Collecting pandas<3,>=2.3 (from datarec-lib)
#   Downloading pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: scikit-learn<2,>=1.6 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from datarec-lib) (1.6.1)
# Requirement already satisfied: tqdm<5,>=4.64 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from datarec-lib) (4.67.1)
# Collecting gdown<5,>=4.7 (from datarec-lib)
#   Downloading gdown-4.7.3-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: requests<3,>=2.28 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from datarec-lib) (2.32.3)
# Collecting py7zr<1,>=0.22 (from datarec-lib)
#   Downloading py7zr-0.22.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: PyYAML<7,>=6.0 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from datarec-lib) (6.0.2)
# Collecting platformdirs<5,>=4.4.0 (from datarec-lib)
#   Downloading platformdirs-4.5.1-py3-none-any.whl.metadata (12 kB)
# Collecting appdirs<2,>=1.4.4 (from datarec-lib)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: typing_extensions in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from datarec-lib) (4.12.2)
# Requirement already satisfied: networkx<4,>=3.2 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from datarec-lib) (3.5)
# Collecting python-igraph<2,>=1.0 (from datarec-lib)
#   Downloading python_igraph-1.0.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting PySocks<2,>=1.7 (from datarec-lib)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from gdown<5,>=4.7->datarec-lib) (3.18.0)
# Requirement already satisfied: six in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from gdown<5,>=4.7->datarec-lib) (1.17.0)
# Collecting beautifulsoup4 (from gdown<5,>=4.7->datarec-lib)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from pandas<3,>=2.3->datarec-lib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from pandas<3,>=2.3->datarec-lib) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from pandas<3,>=2.3->datarec-lib) (2025.2)
# Collecting texttable (from py7zr<1,>=0.22->datarec-lib)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting pycryptodomex>=3.16.0 (from py7zr<1,>=0.22->datarec-lib)
#   Downloading pycryptodomex-3.23.0-cp37-abi3-win_amd64.whl.metadata (3.5 kB)
# Collecting pyzstd>=0.15.9 (from py7zr<1,>=0.22->datarec-lib)
#   Downloading pyzstd-0.19.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyppmd<1.2.0,>=1.1.0 (from py7zr<1,>=0.22->datarec-lib)
#   Downloading pyppmd-1.1.1-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr<1,>=0.22->datarec-lib)
#   Downloading pybcj-1.0.7-cp311-cp311-win_amd64.whl.metadata (4.0 kB)
# Collecting multivolumefile>=0.2.3 (from py7zr<1,>=0.22->datarec-lib)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr<1,>=0.22->datarec-lib)
#   Downloading inflate64-1.0.4-cp311-cp311-win_amd64.whl.metadata (4.5 kB)
# Collecting brotli>=1.1.0 (from py7zr<1,>=0.22->datarec-lib)
#   Downloading brotli-1.2.0-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: psutil in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from py7zr<1,>=0.22->datarec-lib) (5.9.0)
# Collecting igraph==1.0.0 (from python-igraph<2,>=1.0->datarec-lib)
#   Downloading igraph-1.0.0-cp39-abi3-win_amd64.whl.metadata (4.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from requests<3,>=2.28->datarec-lib) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from requests<3,>=2.28->datarec-lib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from requests<3,>=2.28->datarec-lib) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from requests<3,>=2.28->datarec-lib) (2025.4.26)
# Requirement already satisfied: scipy>=1.6.0 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from scikit-learn<2,>=1.6->datarec-lib) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from scikit-learn<2,>=1.6->datarec-lib) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from scikit-learn<2,>=1.6->datarec-lib) (3.6.0)
# Requirement already satisfied: colorama in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from tqdm<5,>=4.64->datarec-lib) (0.4.6)
# Collecting backports-zstd>=1.0.0 (from pyzstd>=0.15.9->py7zr<1,>=0.22->datarec-lib)
#   Downloading backports_zstd-1.3.0-cp311-cp311-win_amd64.whl.metadata (7.1 kB)
# Collecting typing_extensions (from datarec-lib)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->gdown<5,>=4.7->datarec-lib)
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Downloading datarec_lib-1.5.2-py3-none-any.whl (166 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading gdown-4.7.3-py3-none-any.whl (16 kB)
# Downloading pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ------------------------- -------------- 7.3/11.3 MB 56.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 35.5 MB/s eta 0:00:00
# Downloading platformdirs-4.5.1-py3-none-any.whl (18 kB)
# Downloading py7zr-0.22.0-py3-none-any.whl (67 kB)
# Downloading inflate64-1.0.4-cp311-cp311-win_amd64.whl (35 kB)
# Downloading pybcj-1.0.7-cp311-cp311-win_amd64.whl (24 kB)
# Downloading pyppmd-1.1.1-cp311-cp311-win_amd64.whl (46 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading python_igraph-1.0.0-py3-none-any.whl (9.2 kB)
# Downloading igraph-1.0.0-cp39-abi3-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 3.2/3.2 MB 15.8 MB/s eta 0:00:00
# Downloading brotli-1.2.0-cp311-cp311-win_amd64.whl (369 kB)
# Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Downloading pycryptodomex-3.23.0-cp37-abi3-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 12.3 MB/s eta 0:00:00
# Downloading pyzstd-0.19.1-py3-none-any.whl (23 kB)
# Downloading backports_zstd-1.3.0-cp311-cp311-win_amd64.whl (313 kB)
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Installing collected packages: texttable, brotli, appdirs, typing_extensions, soupsieve, PySocks, pyppmd, pycryptodomex, pybcj, platformdirs, multivolumefile, inflate64, igraph, backports-zstd, pyzstd, python-igraph, pandas, beautifulsoup4, py7zr, gdown, datarec-lib
#
#    ----------------------------------------  0/21 [texttable]
#   Attempting uninstall: typing_extensions
#    ----------------------------------------  0/21 [texttable]
#     Found existing installation: typing_extensions 4.12.2
#    ----------------------------------------  0/21 [texttable]
#    ----- ----------------------------------  3/21 [typing_extensions]
#     Uninstalling typing_extensions-4.12.2:
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ----- ----------------------------------  3/21 [typing_extensions]
#    ------- --------------------------------  4/21 [soupsieve]
#    ------- --------------------------------  4/21 [soupsieve]
#    ------- --------------------------------  4/21 [soupsieve]
#    ----------- ----------------------------  6/21 [pyppmd]
#    ----------- ----------------------------  6/21 [pyppmd]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    ------------- --------------------------  7/21 [pycryptodomex]
#    --------------- ------------------------  8/21 [pybcj]
#   Attempting uninstall: platformdirs
#    --------------- ------------------------  8/21 [pybcj]
#     Found existing installation: platformdirs 4.3.7
#    --------------- ------------------------  8/21 [pybcj]
#    ----------------- ----------------------  9/21 [platformdirs]
#     Uninstalling platformdirs-4.3.7:
#    ----------------- ----------------------  9/21 [platformdirs]
#       Successfully uninstalled platformdirs-4.3.7
#    ----------------- ----------------------  9/21 [platformdirs]
#    ----------------- ----------------------  9/21 [platformdirs]
#    ----------------- ----------------------  9/21 [platformdirs]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ---------------------- ----------------- 12/21 [igraph]
#    ------------------------ --------------- 13/21 [backports-zstd]
#    ------------------------ --------------- 13/21 [backports-zstd]
#    ------------------------ --------------- 13/21 [backports-zstd]
#    ------------------------ --------------- 13/21 [backports-zstd]
#    -------------------------- ------------- 14/21 [pyzstd]
#   Attempting uninstall: pandas
#    -------------------------- ------------- 14/21 [pyzstd]
#     Found existing installation: pandas 2.2.3
#    -------------------------- ------------- 14/21 [pyzstd]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#     Uninstalling pandas-2.2.3:
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#       Successfully uninstalled pandas-2.2.3
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    ------------------------------ --------- 16/21 [pandas]
#    -------------------------------- ------- 17/21 [beautifulsoup4]
#    -------------------------------- ------- 17/21 [beautifulsoup4]
#    -------------------------------- ------- 17/21 [beautifulsoup4]
#    -------------------------------- ------- 17/21 [beautifulsoup4]
#    -------------------------------- ------- 17/21 [beautifulsoup4]
#    ---------------------------------- ----- 18/21 [py7zr]
#    ---------------------------------- ----- 18/21 [py7zr]
#    ---------------------------------- ----- 18/21 [py7zr]
#    ------------------------------------ --- 19/21 [gdown]
#    ------------------------------------ --- 19/21 [gdown]
#    ------------------------------------ --- 19/21 [gdown]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    -------------------------------------- - 20/21 [datarec-lib]
#    ---------------------------------------- 21/21 [datarec-lib]
#
# Successfully installed PySocks-1.7.1 appdirs-1.4.4 backports-zstd-1.3.0 beautifulsoup4-4.14.3 brotli-1.2.0 datarec-lib-1.5.2 gdown-4.7.3 igraph-1.0.0 inflate64-1.0.4 multivolumefile-0.2.3 pandas-2.3.3 platformdirs-4.5.1 py7zr-0.22.0 pybcj-1.0.7 pycryptodomex-3.23.0 pyppmd-1.1.1 python-igraph-1.0.0 pyzstd-0.19.1 soupsieve-2.8.3 texttable-1.7.0 typing_extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# msclap 1.3.4 requires transformers<5.0.0,>=4.34.0, but you have transformers 5.0.0 which is incompatible.

# %% [markdown]
# **General rules of thumb for homeworks:**
# - Read the homework questions carefully.
# - Explain your choices.
# - Present your findings concisely.
# - Use tables, plots, and summary statistics to aid your presentation of findings.
# - If you have an idea in mind but could not implement (in code), present the idea thoroughly and how you would have implemented the code.

# %% [markdown]
# ### Tasks:
#
# For all tasks below, create one or more functions for each step such that a sequence of functions may be run for a full analysis.  Specify the sequence of functions and their brief descriptions in the README.

# %% [markdown]
# 1. Download the MovieLens 1m dataset.  You should output a copy of the dataset on an AWS S3 bucket.
#     - Check if your S3 bucket already contains the dataset. If so, the script should not actually download the dataset.

# %%
# %pip install boto3 requests
# Out:
# Collecting boto3
#   Downloading boto3-1.42.43-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: requests in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (2.32.3)
# Collecting botocore<1.43.0,>=1.42.43 (from boto3)
#   Downloading botocore-1.42.43-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from botocore<1.43.0,>=1.42.43->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from botocore<1.43.0,>=1.42.43->boto3) (2.4.0)
# Requirement already satisfied: six>=1.5 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.43->boto3) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\0-kathy cui\0-northwestern\0-classes\3rd year\spring 2025\cs352\.conda\lib\site-packages (from requests) (2025.4.26)
# Downloading boto3-1.42.43-py3-none-any.whl (140 kB)
# Downloading botocore-1.42.43-py3-none-any.whl (14.6 MB)
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ------------------- -------------------- 7.1/14.6 MB 54.5 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 38.3 MB/s eta 0:00:00
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
#
#    ---------------------------------------- 0/4 [jmespath]
#    ---------------------------------------- 0/4 [jmespath]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    ---------- ----------------------------- 1/4 [botocore]
#    -------------------- ------------------- 2/4 [s3transfer]
#    -------------------- ------------------- 2/4 [s3transfer]
#    -------------------- ------------------- 2/4 [s3transfer]
#    -------------------- ------------------- 2/4 [s3transfer]
#    ------------------------------ --------- 3/4 [boto3]
#    ------------------------------ --------- 3/4 [boto3]
#    ------------------------------ --------- 3/4 [boto3]
#    ------------------------------ --------- 3/4 [boto3]
#    ------------------------------ --------- 3/4 [boto3]
#    ------------------------------ --------- 3/4 [boto3]
#    ------------------------------ --------- 3/4 [boto3]
#    ------------------------------ --------- 3/4 [boto3]
#    ---------------------------------------- 4/4 [boto3]
#
# Successfully installed boto3-1.42.43 botocore-1.42.43 jmespath-1.1.0 s3transfer-0.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3

source_bucket = "dinglin-winter26"
source_prefix = "lab4/ml-1m/"
dest_bucket = "kat-winter26"
dest_prefix = "datasets/movielens/"

s3 = boto3.client("s3")

# Check if destination already has data
resp = s3.list_objects_v2(Bucket=dest_bucket, Prefix=dest_prefix, MaxKeys=1)
if "Contents" in resp:
    print("Dataset already exists in your bucket. Skipping.")
else:
    paginator = s3.get_paginator("list_objects_v2")
    for page in paginator.paginate(Bucket=source_bucket, Prefix=source_prefix):
        for obj in page.get("Contents", []):
            src_key = obj["Key"]
            dst_key = src_key.replace(source_prefix, dest_prefix, 1)

            copy_source = {"Bucket": source_bucket, "Key": src_key}
            s3.copy(copy_source, dest_bucket, dst_key)
            print(f"Copied {src_key} → {dst_key}")
# Out:
# ---------------------------------------------------------------------------
# AccessDenied                              Traceback (most recent call last)
# Cell In[4], line 11
#       8 s3 = boto3.client("s3")
#      10 # Check if destination already has data
# ---> 11 resp = s3.list_objects_v2(Bucket=dest_bucket, Prefix=dest_prefix, MaxKeys=1)
#      12 if "Contents" in resp:
#      13     print("Dataset already exists in your bucket. Skipping.")
#
# File c:\0-Kathy Cui\0-Northwestern\0-Classes\3rd Year\Spring 2025\CS352\.conda\Lib\site-packages\botocore\client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File c:\0-Kathy Cui\0-Northwestern\0-Classes\3rd Year\Spring 2025\CS352\.conda\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\0-Kathy Cui\0-Northwestern\0-Classes\3rd Year\Spring 2025\CS352\.conda\Lib\site-packages\botocore\client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1074     error_code = request_context.get(
#    1075         'error_code_override'
#    1076     ) or error_info.get("Code")
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#    1080     return parsed_response
#
# AccessDenied: An error occurred (AccessDenied) when calling the ListObjectsV2 operation: Access Denied

# %% [markdown]
# 2. Create embeddings for the BERT algorithm.  For the same set of items (movies) in the dataset, you should create the embeddings once and output a copy of the necessary intermediate results on the S3 bucket.
#     - This is the *offline* step, where embeddings only need to be created once for the recommendation system.
#     - Use a random subset (30%) of users in the available dataset.

# %% [markdown]
# 3. Recommend five movies for each of the following users.  The recommendations should be saved in a file on the S3 bucket containing `User_Type`, `Last_Interaction_Time`, other user summaries in the dataset,and a list of recommended movies:
#     - *Cold user*: a user that the system has no data on.
#     - *Top user*: a random user who has frequently rated movies (number of interactions among the top 5\% of users).

# %% [markdown]
# 4. Repeat steps 2 and 3 but with the full set of data.  You should be able to reuse your work from earlier.

# %% [markdown]
# 5. Choose and rate 10 movies and create a "user profile" for yourself.  Save your user profile on the S3 bucket.  Recommend 5 movies for yourself and save the results on the S3 bucket.

# %% [markdown]
# # Submission guidelines
# Your submission should be contained in a `homework_2` folder of your Github repository, and it should include
# - a `readme.md` file including how to run the code and what your expected outputs are (if the code is run),
# - your source code, and/or
# - a `.pdf` or `.html` file containing any necessary observations and details.
#     - If you find your source code self-explanatory, you may opt to skip the `.pdf` or `.html` file in this homework.

# %% [markdown]
# # Generative AI disclosure
#
# *Syllabus* policy:
#
# Required disclosure: each submission must include an AI Usage note stating: (1) tool(s) used, (2) the key prompt(s), and (3) what you changed and how you verified the results. If none, write: “AI Usage: None.”
